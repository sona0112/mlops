# %% [markdown]
# # End to End Model Development and Deployment

# %% [markdown]
# Diabetics is a Chronic disease that affects millions worldwide. Particularly we are interested to analyze diabetes in female patients.
#
# **Problem Statement**
# Develop a machine learning model to predict diabtes in women and deploy it as a Web App in Streamlit
#
# **Dataset Description**
# This is the Pima Indians Dataset from kaggle.com and has data about 768 women of Pima heritage 21 years and above. This is an open source dataset.
#
# **Steps of the Modelling Process**
# 1. Import all libraries and view the data set
# 2. Do the Data Sanity Check
# 3. Clean the data
# 4. Perform Exploratory Data Analysis
# 5. Preprocess the data for modelling
# 6. Fit and evaluate Machine Learning Models
# 7. Optimize the best model
# 8. Interpret the tuned model
# 9. Prepare for deployment by creating a pipeline
# 10. Deploy in Streamlit

# %% [markdown]
# ### Step1: Import libraries and the datset

# %%
# data manipulation and EDA libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# data preprocessing libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE

# data modelling libraries
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# data metrics libraries
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report

# model interpretation and deployment libraries
import shap
import pickle
from sklearn.pipeline import Pipeline
import streamlit as st

print("All libraries are imported")
# Out:
# All libraries are imported

# %%
# !pip install xgboost --quiet

# %%
# !pip install shap

# %%
# !pip install streamlit

# %%
data=pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age          Outcome
# 0                     0.627   50              Yes
# 1                     0.351   31               No
# 2                     0.672   32              Yes
# 3                     0.167   21               No
# 4                     2.288   33  Tested_Positive

# %% [markdown]
# **Attributes of the data**
# 1. Pregnancies- The number of times the patient was pregnant
# 2. Glucose- The serum glucose level of the patient
# 3. BloodPressure- Duastolic blood pressure(mm of Hg)
# 4. SkinThickness- Triceps fold skin thickness ( mm)
# 5. Insulin - The serum insulin level of te patient
# 6. BMI- Body Mass Index ( Wt/Ht^2) is a measure of obesity
# 7. DiabetisPedigreeFunction- A genetic propensity towards diabtes base on family history
# 8. Age - Age of the patient
# 9. Outcome- The target variable withh two levels (Yes/No)

# %% [markdown]
# ### Step2 : Data Sanity Check
# - get the basic info of the data
# - look for null values
# - look for duplicate rows
# - look for corrupted data
# - get the data summary statistics(both numerical and categorical)
# - look for erroneous values in the data

# %%
# get the shape of the data 
data_shape=data.shape
print('Rows =', data_shape[0], ' Columns=', data_shape[1])
# Out:
# Rows = 768  Columns= 9

# %%
# get the basic info
info=data.info()

# get the data type
dtype=data.dtypes

info, dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 54.1+ KB
# (None,
#  Pregnancies                   int64
#  Glucose                       int64
#  BloodPressure                 int64
#  SkinThickness                 int64
#  Insulin                       int64
#  BMI                         float64
#  DiabetesPedigreeFunction    float64
#  Age                           int64
#  Outcome                      object
#  dtype: object)

# %%
# check for unique levels in categorical
data['Outcome'].nunique()
# Out:
# 4

# %%
# get the vakue counds
data['Outcome'].value_counts()
# Out:
# No                 470
# Yes                248
# Tested_Negative     30
# Tested_Positive     20
# Name: Outcome, dtype: int64

# %%
#check for nulls and duplicate 
nulls=data.isnull().sum()

dups=data.duplicated().sum()

nulls, dups
# Out:
# (Pregnancies                 0
#  Glucose                     0
#  BloodPressure               0
#  SkinThickness               0
#  Insulin                     0
#  BMI                         0
#  DiabetesPedigreeFunction    0
#  Age                         0
#  Outcome                     0
#  dtype: int64,
#  0)

# %%
# look for corrupt characters in the data 
data[~data.applymap(np.isreal).any(1)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Summary statistics of numerical anad categorical data 
num_stats=data.describe().T
cat_stats=data.describe(include='O').T
num_stats, cat_stats
# Out:
# (                          count        mean         std     min       25%  \
#  Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
#  Glucose                   768.0  120.894531   31.972618   0.000  99.00000
#  BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
#  SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
#  Insulin                   768.0   79.799479  115.244002   0.000   0.00000
#  BMI                       768.0   31.992578    7.884160   0.000  27.30000
#  DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
#  Age                       768.0   33.240885   11.760232  21.000  24.00000
#
#                                 50%        75%     max
#  Pregnancies                 3.0000    6.00000   17.00
#  Glucose                   117.0000  140.25000  199.00
#  BloodPressure              72.0000   80.00000  122.00
#  SkinThickness              23.0000   32.00000   99.00
#  Insulin                    30.5000  127.25000  846.00
#  BMI                        32.0000   36.60000   67.10
#  DiabetesPedigreeFunction    0.3725    0.62625    2.42
#  Age                        29.0000   41.00000   81.00  ,
#          count unique top freq
#  Outcome   768      4  No  470)

# %% [markdown]
# **Data Summary**
# 1. The dataset has 768 rows and 9 columns
# 2. The dataset has 8 numerical varibles ( int64 and float64) and one categorical variable (Ouctome)
# 3. **The categorical variable Outcome has 4 levels which we need to clean and reduce to 2 levels (Yes=1 /No=0)**
# 3. There are no missing values or duplicate rows
# 4. There are no corrupt characters in the data
# 5. **There are many columns which have minimun vaue as 0 , that is physiologically not feasible, so we have ti impute them with column medians**

# %% [markdown]
# ### Step3: Data cleaning Step
# - encode categorical Outcome variable
# - impute columns with minimum value 0

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# create a copy of the data
df=data.copy()

# %%
# imputing the 0 values
cols=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']
zerofill=lambda x: x.replace(0, x.median())
df[cols]=df[cols].apply(zerofill, 0)

# %%
#check the minimum values
df[df.columns[:]].agg('min')
# Out:
# Pregnancies                     0
# Glucose                        44
# BloodPressure                  24
# SkinThickness                   7
# Insulin                      14.0
# BMI                          18.2
# DiabetesPedigreeFunction    0.078
# Age                            21
# Outcome                        No
# dtype: object

# %%
# categorical encoding
d={
    'Yes':1,'Tested_Positive':1, 'No':0, 'Tested_Negative':0
}
df['Outcome']=df["Outcome"].map(d)
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Step4: Exploratory Data Analysis
# - univariate analysis
#    - numerical data - histograms and boxplots
#    - categorical data - bar plots
# - Bivariate analysis
#    - bivariate bar charts
#    - scatter plots
# - Correlation analyis
#    - Correlation matrix and heatmaps

# %%
# Univariate analyis for numerical data 
df.hist()
plt.tight_layout()
plt.show()

# %%
# create individual box plots and histplots
def histplot_boxplot(data, feature, figsize=(12, 7), bins=None):
    print("Univarites for ...", feature)
    fig, (ax_box, ax_hist)=plt.subplots(
    nrows=2,
    sharex=True,
    gridspec_kw={'height_ratios':(0.25, 0.75)},
    figsize=figsize)
    sns.boxplot(data=data, x=feature, color='violet', ax=ax_box, showmeans=True)
    sns.histplot(data=data, x=feature, ax=ax_hist, bins=bins ) if bins else sns.histplot(data=data, x=feature, ax=ax_hist)
    plt.axvline(data[feature].mean(), color='green', linestyle='--')
    plt.axvline(data[feature].median(), color='black', linestyle='-')
    plt.show()

# %%
for col in df.select_dtypes(exclude='O').columns:
    histplot_boxplot(data=df, feature=col)
# Out:
# Univarites for ... Pregnancies
# Univarites for ... Glucose
# Univarites for ... BloodPressure
# Univarites for ... SkinThickness
# Univarites for ... Insulin
# Univarites for ... BMI
# Univarites for ... DiabetesPedigreeFunction
# Univarites for ... Age
# Univarites for ... Outcome

# %%
num_outliers={}
for col in df.columns:
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    outliers=((df[col]< (q1-1.5*iqr)) | (df[col]>(q3+1.5*iqr)))
    num_outliers[col]=outliers.sum()
num_outliers
# Out:
# {'Pregnancies': 4,
#  'Glucose': 0,
#  'BloodPressure': 14,
#  'SkinThickness': 35,
#  'Insulin': 49,
#  'BMI': 8,
#  'DiabetesPedigreeFunction': 29,
#  'Age': 9,
#  'Outcome': 0}

# %%
# univariate barchart for categorical Outcome
plt.figure(figsize=(12,7))
ax=sns.countplot(df['Outcome'], color='green' )
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate("{:.2g}%".format(100.*y/len(df)), (x.mean(), y), ha='center', va='bottom')
plt.title('Univariate Bar Chart fpr Outcome')
plt.show()

# %% [markdown]
# **Bivariate Analysis**
# - bivarite bar graph

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
cols=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']
for col in cols:
    print("Bivariates between Outcome and {}".format(col))
    df.groupby('Outcome')[col].mean().plot(kind='bar', color='orange')
    plt.show()
# Out:
# Bivariates between Outcome and Pregnancies
# Bivariates between Outcome and Glucose
# Bivariates between Outcome and BloodPressure
# Bivariates between Outcome and SkinThickness
# Bivariates between Outcome and Insulin
# Bivariates between Outcome and BMI
# Bivariates between Outcome and DiabetesPedigreeFunction
# Bivariates between Outcome and Age

# %%
# pairplot
sns.pairplot(df, hue='Outcome')

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(), annot=True, cmap='Spectral', vmax=+1, vmin=-1)
plt.show()

# %% [markdown]
# **Observations**
# 1. Pregnancies , insulin, DiabetesPedigreeFunction and age are rights skewed
# 2. BloodPressure, Insulin, SkinThickness , Diabetes predigree function had many outliers
# 3. Outliers counts have been obtained but we will not resolve these outliers
# 4. The Outcome variable is highly imbalanced with 65% having diabetes and 35% not having diabetes
# 5. Women with higher Pregnancies, Glucose, BMI, Age, Diabetes Pedigree Function are more prone to diabetes. To confirm this we will use pairplots an heatmaps.
# 6. Base on KDE plots the distributions of Pregnancies,Glucose, Age, Diabetes Pedigree Function are much different for the two outcome classes showing that they are risk factors of diabtes
# 7. Scatter plots show strong positive trend between Glucose and Insulin, Glucose and BMI, Glucose and age. These may be risk factors of diabetes. We confirm with a heatmap
# 8. Heatmap shows that Glucose, BMI and Age are risk factors of Diabetes

# %% [markdown]
# ### Step5: Data Preprocessing

# %%
    x=df.drop('Outcome', axis=1)
    y=df['Outcome']
    sm=SMOTE()
    x,y=sm.fit_resample(x,y)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,stratify=y)

# %%
xtrain.shape
# Out:
# (750, 8)

# %%
xtest.shape
# Out:
# (250, 8)

# %%
ytrain.shape
# Out:
# (750,)

# %%
from pycaret.classification import *

# %%
setup(df,target='Outcome', remove_multicollinearity=True, preprocess=True)
# Out:
# <style type="text/css">
# #T_34681_row8_col1, #T_34681_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_34681">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34681_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_34681_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34681_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34681_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_34681_row0_col1" class="data row0 col1" >1650</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34681_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_34681_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34681_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_34681_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34681_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_34681_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34681_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_34681_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34681_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_34681_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34681_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_34681_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34681_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_34681_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34681_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_34681_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34681_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_34681_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_34681_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_34681_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_34681_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_34681_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_34681_row12_col0" class="data row12 col0" >Remove multicollinearity</td>
#       <td id="T_34681_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_34681_row13_col0" class="data row13 col0" >Multicollinearity threshold</td>
#       <td id="T_34681_row13_col1" class="data row13 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_34681_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_34681_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_34681_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_34681_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_34681_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_34681_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_34681_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_34681_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_34681_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_34681_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_34681_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_34681_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_34681_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_34681_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_34681_row20_col1" class="data row20 col1" >60fc</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_3a5b6 th {
#   text-align: left;
# }
# #T_3a5b6_row0_col0, #T_3a5b6_row0_col3, #T_3a5b6_row0_col4, #T_3a5b6_row1_col0, #T_3a5b6_row1_col1, #T_3a5b6_row1_col2, #T_3a5b6_row1_col3, #T_3a5b6_row1_col5, #T_3a5b6_row1_col6, #T_3a5b6_row1_col7, #T_3a5b6_row2_col0, #T_3a5b6_row2_col1, #T_3a5b6_row2_col2, #T_3a5b6_row2_col3, #T_3a5b6_row2_col4, #T_3a5b6_row2_col5, #T_3a5b6_row2_col6, #T_3a5b6_row2_col7, #T_3a5b6_row3_col0, #T_3a5b6_row3_col1, #T_3a5b6_row3_col2, #T_3a5b6_row3_col3, #T_3a5b6_row3_col4, #T_3a5b6_row3_col5, #T_3a5b6_row3_col6, #T_3a5b6_row3_col7, #T_3a5b6_row4_col0, #T_3a5b6_row4_col1, #T_3a5b6_row4_col2, #T_3a5b6_row4_col3, #T_3a5b6_row4_col4, #T_3a5b6_row4_col5, #T_3a5b6_row4_col6, #T_3a5b6_row4_col7, #T_3a5b6_row5_col0, #T_3a5b6_row5_col1, #T_3a5b6_row5_col2, #T_3a5b6_row5_col3, #T_3a5b6_row5_col4, #T_3a5b6_row5_col5, #T_3a5b6_row5_col6, #T_3a5b6_row5_col7, #T_3a5b6_row6_col0, #T_3a5b6_row6_col1, #T_3a5b6_row6_col2, #T_3a5b6_row6_col4, #T_3a5b6_row6_col5, #T_3a5b6_row6_col6, #T_3a5b6_row6_col7, #T_3a5b6_row7_col0, #T_3a5b6_row7_col1, #T_3a5b6_row7_col2, #T_3a5b6_row7_col3, #T_3a5b6_row7_col4, #T_3a5b6_row7_col5, #T_3a5b6_row7_col6, #T_3a5b6_row7_col7, #T_3a5b6_row8_col0, #T_3a5b6_row8_col1, #T_3a5b6_row8_col2, #T_3a5b6_row8_col3, #T_3a5b6_row8_col4, #T_3a5b6_row8_col5, #T_3a5b6_row8_col6, #T_3a5b6_row8_col7, #T_3a5b6_row9_col0, #T_3a5b6_row9_col1, #T_3a5b6_row9_col2, #T_3a5b6_row9_col3, #T_3a5b6_row9_col4, #T_3a5b6_row9_col5, #T_3a5b6_row9_col6, #T_3a5b6_row9_col7, #T_3a5b6_row10_col0, #T_3a5b6_row10_col1, #T_3a5b6_row10_col2, #T_3a5b6_row10_col3, #T_3a5b6_row10_col4, #T_3a5b6_row10_col5, #T_3a5b6_row10_col6, #T_3a5b6_row10_col7, #T_3a5b6_row11_col0, #T_3a5b6_row11_col1, #T_3a5b6_row11_col2, #T_3a5b6_row11_col3, #T_3a5b6_row11_col4, #T_3a5b6_row11_col5, #T_3a5b6_row11_col6, #T_3a5b6_row11_col7, #T_3a5b6_row12_col0, #T_3a5b6_row12_col1, #T_3a5b6_row12_col2, #T_3a5b6_row12_col3, #T_3a5b6_row12_col4, #T_3a5b6_row12_col5, #T_3a5b6_row12_col6, #T_3a5b6_row12_col7, #T_3a5b6_row13_col0, #T_3a5b6_row13_col1, #T_3a5b6_row13_col2, #T_3a5b6_row13_col3, #T_3a5b6_row13_col4, #T_3a5b6_row13_col5, #T_3a5b6_row13_col6, #T_3a5b6_row13_col7, #T_3a5b6_row14_col0, #T_3a5b6_row14_col1, #T_3a5b6_row14_col2, #T_3a5b6_row14_col3, #T_3a5b6_row14_col4, #T_3a5b6_row14_col5, #T_3a5b6_row14_col6, #T_3a5b6_row14_col7 {
#   text-align: left;
# }
# #T_3a5b6_row0_col1, #T_3a5b6_row0_col2, #T_3a5b6_row0_col5, #T_3a5b6_row0_col6, #T_3a5b6_row0_col7, #T_3a5b6_row1_col4, #T_3a5b6_row6_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3a5b6_row0_col8, #T_3a5b6_row1_col8, #T_3a5b6_row2_col8, #T_3a5b6_row3_col8, #T_3a5b6_row4_col8, #T_3a5b6_row5_col8, #T_3a5b6_row6_col8, #T_3a5b6_row7_col8, #T_3a5b6_row8_col8, #T_3a5b6_row9_col8, #T_3a5b6_row10_col8, #T_3a5b6_row11_col8, #T_3a5b6_row12_col8, #T_3a5b6_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3a5b6_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3a5b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a5b6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3a5b6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3a5b6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3a5b6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3a5b6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3a5b6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3a5b6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3a5b6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3a5b6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a5b6_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_3a5b6_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3a5b6_row0_col1" class="data row0 col1" >0.7804</td>
#       <td id="T_3a5b6_row0_col2" class="data row0 col2" >0.8439</td>
#       <td id="T_3a5b6_row0_col3" class="data row0 col3" >0.5829</td>
#       <td id="T_3a5b6_row0_col4" class="data row0 col4" >0.7362</td>
#       <td id="T_3a5b6_row0_col5" class="data row0 col5" >0.6492</td>
#       <td id="T_3a5b6_row0_col6" class="data row0 col6" >0.4924</td>
#       <td id="T_3a5b6_row0_col7" class="data row0 col7" >0.5006</td>
#       <td id="T_3a5b6_row0_col8" class="data row0 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_3a5b6_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_3a5b6_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_3a5b6_row1_col1" class="data row1 col1" >0.7785</td>
#       <td id="T_3a5b6_row1_col2" class="data row1 col2" >0.8436</td>
#       <td id="T_3a5b6_row1_col3" class="data row1 col3" >0.5723</td>
#       <td id="T_3a5b6_row1_col4" class="data row1 col4" >0.7380</td>
#       <td id="T_3a5b6_row1_col5" class="data row1 col5" >0.6430</td>
#       <td id="T_3a5b6_row1_col6" class="data row1 col6" >0.4861</td>
#       <td id="T_3a5b6_row1_col7" class="data row1 col7" >0.4956</td>
#       <td id="T_3a5b6_row1_col8" class="data row1 col8" >1.4000</td>
#     </tr>
#     <tr>
#       <th id="T_3a5b6_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_3a5b6_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_3a5b6_row2_col1" class="data row2 col1" >0.7766</td>
#       <td id="T_3a5b6_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_3a5b6_row2_col3" class="data row2 col3" >0.5669</td>
#       <td id="T_3a5b6_row2_col4" class="data row2 col4" >0.7359</td>
#       <td id="T_3a5b6_row2_col5" class="data row2 col5" >0.6394</td>
#       <td id="T_3a5b6_row2_col6" class="data row2 col6" >0.4813</td>
#       <td id="T_3a5b6_row2_col7" class="data row2 col7" >0.4907</td>
#       <td id="T_3a5b6_row2_col8" class="data row2 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_3a5b6_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_3a5b6_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3a5b6_row3_col1" class="data row3 col1" >0.7692</td>
#       <td id="T_3a5b6_row3_col2" class="data row3 col2" >0.8231</td>
#       <td id="T_3a5b6_row3_col3" class="data row3 col3" >0.6038</td>
#       <td id="T_3a5b6_row3_col4" class="data row3 col4" >0.6992</td>
#       <td id="T_3a5b6_row3_col5" class="data row3 col5" >0.6433</td>
#       <td id="T_3a5b6_row3_col6" class="data row3 col6" >0.4747</td>
#       <td id="T_3a5b6_row3_col7" class="data row3 col7" >0.4811</td>
#       <td id="T_3a5b6_row3_col8" class="data row3 col8" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_3a5b6_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_3a5b6_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_3a5b6_row4_col1" class="data row4 col1" >0.7673</td>
#       <td id="T_3a5b6_row4_col2" class="data row4 col2" >0.8273</td>
#       <td id="T_3a5b6_row4_col3" class="data row4 col3" >0.5774</td>
#       <td id="T_3a5b6_row4_col4" class="data row4 col4" >0.7034</td>
#       <td id="T_3a5b6_row4_col5" class="data row4 col5" >0.6330</td>
#       <td id="T_3a5b6_row4_col6" class="data row4 col6" >0.4651</td>
#       <td id="T_3a5b6_row4_col7" class="data row4 col7" >0.4708</td>
#       <td id="T_3a5b6_row4_col8" class="data row4 col8" >0.2960</td>
#     </tr>
#     <tr>
#       <th id="T_3a5b6_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_3a5b6_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_3a5b6_row5_col1" class="data row5 col1" >0.7654</td>
#       <td id="T_3a5b6_row5_col2" class="data row5 col2" >0.8273</td>
#       <td id="T_3a5b6_row5_col3" class="data row5 col3" >0.5717</td>
#       <td id="T_3a5b6_row5_col4" class="data row5 col4" >0.7043</td>
#       <td id="T_3a5b6_row5_col5" c
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %%
lr=LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
lr.score(xtest,ytest)
# Out:
# 0.724

# %%
cls = {
    'logreg' : LogisticRegression(),
    'Gaissian Nb': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(),
    'Gboosting' : GradientBoostingClassifier(),
    'AdaBoost' : AdaBoostClassifier(),
    'XGBoost' : XGBClassifier(),
}

# %%
for clf, clf_name in list(zip(cls.values(), cls.keys())):
    clf.fit(xtrain, ytrain)
    ypred = clf.predict(xtest)
    update_performance(clf_name,clf,ytest,ypred)

# %%
perf_score = pd.DataFrame(columns=["Model", "Accuracy","Recall","Precision","F1 Score"] )

def per_measures(model,test,pred):


    accuracy    =accuracy_score(test,pred)
    f1score     =f1_score(test,pred)
    recall      =recall_score(test,pred)
    precision   =precision_score(test,pred)
      # aic         =model.aic
      # reliability = cohen_kappa_score(test,pred)



    return (accuracy,recall,precision,f1score,)

def update_performance (name,
                        model,
                        test,
                        pred
                           ):

    # assign 'comp_perf' as global variable
    global perf_score


    # append the results to the dataframe 'score_card'
    # 'ignore_index = True' do not consider the index labels
    perf_score = perf_score.append({'Model'       : name,
                                    'Accuracy'    : per_measures(model,test,pred)[0],
                                    'Recall'      : per_measures(model,test,pred)[1],
                                    'Precision'   : per_measures(model,test,pred)[2],
                                    'F1 Score'    : per_measures(model,test,pred)[3]
                                    # 'AIC'         : per_measures(model,ytest,ypred)[4],
                                    # 'Reliability' : per_measures(model,ytest,ypred)[5]

                                     },
                                   ignore_index = True)

# %%
perf_score.sort_values(by='F1 Score')
# Out:
#            Model  Accuracy  Recall  Precision  F1 Score
# 1    Gaissian Nb     0.712   0.648   0.743119  0.692308
# 0         logreg     0.724   0.728   0.722222  0.725100
# 5            SVM     0.732   0.712   0.741667  0.726531
# 3  Decision Tree     0.748   0.768   0.738462  0.752941
# 7       AdaBoost     0.776   0.784   0.771654  0.777778
# 6      Gboosting     0.776   0.808   0.759398  0.782946
# 8        XGBoost     0.776   0.824   0.751825  0.786260
# 2            KNN     0.788   0.824   0.768657  0.795367
# 4  Random Forest     0.808   0.864   0.776978  0.818182

# %%
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
ypred=rf.predict(xtest)
test_score=rf.score(xtest,ytest)
train_score=rf.score(xtrain,ytrain)
test_score,train_score
# Out:
# (0.808, 1.0)

# %%
#model is overfitting may be because we balance the data or data is insufficient

# %%
rf = RandomForestClassifier()

param = {'max_depth' : np.arange(10,100,10),'n_estimators':np.arange(100,1000,50),
        'min_samples_split':np.arange(2,10,2),'min_samples_leaf':[1,2,3,4,5],
         'criterion':['gini','entropy'],'max_features':["sqrt", "log2"]
        }
rand =RandomizedSearchCV(rf,param_distributions=param,cv =5,n_jobs=-1,n_iter=100,scoring='f1')

# %%
rand.fit(xtrain,ytrain)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='sqrt',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=100,
#                                                     n_jobs=None,
#                                                     oob_score=False,
#                                                     ra...
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([10, 20, 30, 40, 50, 60, 70, 80, 90]),
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'min_samples_split': array([2, 4, 6, 8]),
#                                         'n_estimators': array([100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700,
#        750, 800, 850, 900, 950])},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='f1', verbose=0)

# %%
rand.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 40,
#  'criterion': 'gini'}

# %%
rfc=RandomForestClassifier(**rand.best_params_)

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=40, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
train_score=rfc.score(xtrain,ytrain)
test_score=rfc.score(xtest,ytest)
train_score,test_score
# Out:
# (1.0, 0.808)

# %%
#deployment

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
sc=StandardScaler()
model=rfc
steps=[('scaler', StandardScaler()),('model',model)]
pipeline=Pipeline(steps)
xtrain,xtest,ytrain,ytest=train_test_split(x,y,stratify=y)

# %%
pipeline.fit(xtrain,ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('model',
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=40, max_features='log2',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=300, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
pipeline.score(xtrain,ytrain)
# Out:
# 1.0

# %%
pipeline.score(xtest,ytest)
# Out:
# 0.84

# %%
#freeze the model

# %%
import pickle

# %%
clf=open('rfc.pickle','wb')
pickle.dump(pipeline,clf)
clf.close()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 4            0      137             40             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data=[[8,183,64,23,30.5,23.3,0.672,32]]
clf=open('rfc.pickle', 'rb')
rfc=pickle.load(clf)
clf.close()
rfc.predict(data)[0]
# Out:
# 1

# %%
#deployment in streamlit

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
from sklearn.preprocessing import StandardScaler
import pickle


st.title('web deployment of medical diagnostic app')
st.subheader('is person diabetic?')
st.set_option('deprecation.showPyplotGlobalUse', False)
df=pd.read_csv('diabetes.csv')
if st.sidebar.checkbox('view data', False):
    st.write(df)
    st.pyplot()
    
if st.sidebar.checkbox('view distributions',False):
    df.hist()
    st.pyplot()

#load pickled model
model=open('rfc.pickle','rb')
clf=pickle.load(model)
model.close()


#get the frondend user input
pregs=st.number_input('Pregnancies',0,17,0), 
glucose=st.slider('Glucose',44,199,44) 
bp=st.slider('BloodPressure',20,140,20) 
skin=st.slider('SkinThickness', 7,99,7)
insulin=st.slider('Insulin',14,850,14)
bmi=st.slider('BMI',18,67,18)
dpf=st.slider('DiabetesPedigreeFunction',0.05,2.50,0.05)
age=st.slider('Age',21,85,21)
# Out:
# Overwriting app.py

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
